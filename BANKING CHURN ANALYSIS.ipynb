# %% [markdown]
# # IMPORING THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # IMPORTING THE DATASETS

# %%
df=pd.read_csv("churn1.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0             1    15634602   Hargrave          619    France  Female  42.0
# 1             2    15647311       Hill          608     Spain  Female  41.0
# 2             3    15619304       Onio          502    France  Female  42.0
# 3             4    15701354       Boni          699    France  Female  39.0
# 4             5    15737888   Mitchell          850     Spain  Female  43.0
# ...         ...         ...        ...          ...       ...     ...   ...
# 9995       9996    15606229   Obijiaku          771    France    Male  39.0
# 9996       9997    15569892  Johnstone          516    France    Male  35.0
# 9997       9998    15584532        Liu          709    France  Female  36.0
# 9998       9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
#To read the first 5 rows of dataset:

df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
#To read last five rows of dataset:

df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male  39.0
# 9996       9997    15569892  Johnstone          516    France    Male  35.0
# 9997       9998    15584532        Liu          709    France  Female  36.0
# 9998       9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999      10000    15628319     Walker          792    France  Female  28.0
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# # BASIC STATISTICS:

# %%
#To understand the information of the dataset:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           9935 non-null   object
#  6   Age              9922 non-null   float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
#To understand the basics statistics of the dataset:

df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore          Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  9922.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800    38.911812      5.012800
# std     2886.89568  7.193619e+04     96.653299    10.465845      2.892174
# min        1.00000  1.556570e+07    350.000000    18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000    32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000    37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000    44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000    92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# # HANDLING MISSING VALUES:

# %%
#To find the missing values in dataset:

df.isnull().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography           0
# Gender             65
# Age                78
# Tenure              0
# Balance             0
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited              0
# dtype: int64

# %%
#To find the index of the rows in the 'Gender' column:

df[df['Gender'].isnull()]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography Gender   Age  \
# 12           13    15632264        Kay          476    France    NaN  34.0
# 34           35    15732963   Clements          722     Spain    NaN  29.0
# 51           52    15768193  Trevisani          585   Germany    NaN  36.0
# 78           79    15575185    Bushell          757     Spain    NaN  33.0
# 93           94    15640635      Capon          769    France    NaN  29.0
# ...         ...         ...        ...          ...       ...    ...   ...
# 8628       8629    15713890    Maclean          704    France    NaN  44.0
# 8664       8665    15666332  Donaldson          690     Spain    NaN  48.0
# 8690       8691    15756167      Doyne          762     Spain    NaN  43.0
# 8726       8727    15570289     Benson          697   Germany    NaN  43.0
# 8767       8768    15585466      Russo          552    France    NaN  29.0
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#To find the index of the rows in the 'Age' column:

df[df['Age'].isnull()]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 16           17    15737452      Romeo          653   Germany    Male  NaN
# 30           31    15589475    Azikiwe          591     Spain  Female  NaN
# 37           38    15729599    Lorenzo          804     Spain    Male  NaN
# 55           56    15760861  Phillipps          619    France    Male  NaN
# 72           73    15812518    Palermo          657     Spain  Female  NaN
# ...         ...         ...        ...          ...       ...     ...  ...
# 8623       8624    15666197       Boni          430   Germany  Female  NaN
# 8661       8662    15604020     Otoole          773   Germany  Female  NaN
# 8686       8687    15597467     Duncan          606    France  Female  NaN
# 8723       8724    15803202  Onyekachi          350    France    Male  NaN
# 8764       8765    15618203       Tien          773   Germany    Male  NaN
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#To find the minimun Age in the dataset:

df['Age'].min()
# Out:
# 18.0

# %%
#To find maximum Age in the dataset:

df['Age'].max()
# Out:
# 92.0

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# #THE MISSING VALUES IN THE'AGE' COLUMN CAN BE FILLED BY FINDING THE MEAN FOR THE 'AGE' COLUMN:

# %%
#To find the mean for the 'Age' column:

df_mean=df['Age'].mean()

#'Age'column is continuous ,so should convert float value to integer value:

df_mean=int(df_mean)
df_mean
# Out:
# 38

# %%
#Filling the null values in'Age' column by 'MEAN':

df['Age_new']=df['Age'].fillna(df_mean)

# %% [markdown]
# #THE MISSING VALUES IN THE'GENDER' COLUMN CAN BE FILLED BY FINDING THE MODE FOR THE 'GENDER' COLUMN:

# %%
#To find the mode for the 'Gender' column:

df['Gender'].value_counts().index[0]
# Out:
# 'Male'

# %%
#Filling the null values in 'Gender'  column by MODE:

df['Gender_new']=df['Gender'].fillna(df['Gender'].value_counts().index[0])
df['Gender_new']
# Out:
# 0       Female
# 1       Female
# 2       Female
# 3       Female
# 4       Female
#          ...
# 9995      Male
# 9996      Male
# 9997    Female
# 9998      Male
# 9999    Female
# Name: Gender_new, Length: 10000, dtype: object

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age_new Gender_new
# 0        101348.88       1     42.0     Female
# 1        112542.58       0     41.0     Female
# ...

# %%
#Dropping "Age","GENDER" columns :

df=df.drop(['Age','Gender'],axis=1)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Tenure    Balance  \
# 0          1    15634602  Hargrave          619    France       2       0.00
# 1          2    15647311      Hill          608     Spain       1   83807.86
# 2          3    15619304      Onio          502    France       8  159660.80
# 3          4    15701354      Boni          699    France       1       0.00
# 4          5    15737888  Mitchell          850     Spain       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  Age_new  \
# 0              1          1               1        101348.88       1     42.0
# 1              1          0               1        112542.58       0     41.0
# 2              3          1               0        113931.57       1     42.0
# 3              2          0               0         93826.63       0     39.0
# 4              1          1               1         79084.10       0     43.0
#
#   Gender_new
# 0     Female
# ...

# %%
# GENERAL FOR LOOP FOR FINDING CATEGORICAL AND NUMERICAL COLUMNS:

cat=[]
num=[]

for column in df.columns:
    if df[column].nunique()> 10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Geography',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'Exited',
#  'Gender_new']

# %%
num
# Out:
# ['RowNumber',
#  'CustomerId',
#  'Surname',
#  'CreditScore',
#  'Tenure',
#  'Balance',
#  'EstimatedSalary',
#  'Age_new']

# %%
#Dropping the columns which are not required for analysis:

df=df.drop(['RowNumber','CustomerId','Surname'],axis=1)
df
# Out:
#       CreditScore Geography  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619    France       2       0.00              1          1
# 1             608     Spain       1   83807.86              1          0
# 2             502    France       8  159660.80              3          1
# 3             699    France       1       0.00              2          0
# 4             850     Spain       2  125510.82              1          1
# ...           ...       ...     ...        ...            ...        ...
# 9995          771    France       5       0.00              2          1
# 9996          516    France      10   57369.61              1          1
# 9997          709    France       7       0.00              1          0
# 9998          772   Germany       3   75075.31              2          1
# 9999          792    France       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Age_new Gender_new
# ...

# %% [markdown]
# # DATA EXPLORATION:

# %% [markdown]
# UNIVARIATE ANALYSIS:

# %%
df.head()
# Out:
#    CreditScore Geography  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619    France       2       0.00              1          1
# 1          608     Spain       1   83807.86              1          0
# 2          502    France       8  159660.80              3          1
# 3          699    France       1       0.00              2          0
# 4          850     Spain       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Age_new Gender_new
# 0               1        101348.88       1     42.0     Female
# 1               1        112542.58       0     41.0     Female
# 2               0        113931.57       1     42.0     Female
# 3               0         93826.63       0     39.0     Female
# 4               1         79084.10       0     43.0     Female

# %%
#Analysis customers who are likely to churn with respect to Gender and Geography:

_,ax=plt.subplots(1,3,figsize=(18,9))
plt.subplots_adjust(wspace=0.3)
sns.countplot(data=df,x="Geography",hue="Gender_new",ax=ax[0])
sns.countplot(data=df,x="Gender_new",hue="Exited",ax=ax[1])
sns.countplot(data=df,x="Geography",hue="Exited",ax=ax[2])
# Out:
# <Axes: xlabel='Geography', ylabel='count'>

# %% [markdown]
# # # ANALYSIS:
#
# ANALYSIS BASED ON GEOGRAPHY:
# The percentage of Males customers are present than Female customers in France,Spain,Germany.
#
# ANALYSIS BASED ON GENDER:
# The Female customers are more likely to churn than Male customers.
#
# ANALYSIS OF CHURN CUSTOMERS BASED ON GEOGRAPHY:
# The customers living in Germany are more likely to churn.

# %% [markdown]
# # Analysis:
#  The Female customers are more likely to churn than the Male customers.

# %%
 _, ax=plt.subplots(1,3,figsize=(18,6))
plt.subplots_adjust(wspace=0.3)
sns.countplot(x= "NumOfProducts",hue="Exited",data=df,ax=ax[0])
sns.countplot(x= "HasCrCard",hue="Exited",data=df,ax=ax[1])
sns.countplot(x= "Tenure",hue="Exited",data=df,ax=ax[2])
# Out:
# <Axes: xlabel='Tenure', ylabel='count'>

# %% [markdown]
# # NUMERICAL ANALYSIS:
#
# ANALYSIS BASED ON NUMOFPRODUCTS:
#
# 1.The users with the 1 num of products has a great rate of churn with 27%.
# 2.The users with the 2 num of products has a lowest rate of churn with 6.9%
#
# ANALYSIS BASED ON HAS CRCARD:
#
# 1.The churn of customers who has a credit card and does'nt have a credit card is same i.e.,20%
#
# ANALYSIS BASED ON TENURE:
#
# 1.The customers with 10 months of tenure has a high churning rate.

# %%
# Adding labels to age bins for analysis:

labels=['0-20','21-40','41-60','61-80','Above 80']
bins=[0,20,40,60,80,100]
df['Age_bins']=pd.cut(df.Age_new,bins,labels=labels,include_lowest=True)
df.head()
# Out:
#    CreditScore Geography  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619    France       2       0.00              1          1
# 1          608     Spain       1   83807.86              1          0
# 2          502    France       8  159660.80              3          1
# 3          699    France       1       0.00              2          0
# 4          850     Spain       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Age_new Gender_new Age_bins
# 0               1        101348.88       1     42.0     Female    41-60
# 1               1        112542.58       0     41.0     Female    41-60
# 2               0        113931.57       1     42.0     Female    41-60
# 3               0         93826.63       0     39.0     Female    21-40
# 4               1         79084.10       0     43.0     Female    41-60

# %%
#Bar chart
plt.bar(labels,df["Age_bins"].value_counts(),label="Age bins")
plt.xlabel("Age")
plt.ylabel("Num of Customers")
plt.title("Churn rate of Customers",fontsize=15)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# Numeric Analysis:
#
# 1.The bank has a high rate of customers between the age 0-20.
# 2.The bank has a lowest rate of customers which are above the age 80.

# %%
#Analyzing the customers with respect to age:

df["Age_new"].value_counts().plot.bar(figsize=(19,5))
# Out:
# <Axes: xlabel='Age_new'>

# %% [markdown]
# The customers with 38 years of age are present in the bank

# %% [markdown]
# # ENCODING:

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df["Geography"]=encoder.fit_transform(df['Geography'])
df['Gender_new']=encoder.fit_transform(df['Gender_new'])
df.head()
# Out:
#    CreditScore  Geography  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619          0       2       0.00              1          1
# 1          608          2       1   83807.86              1          0
# 2          502          0       8  159660.80              3          1
# 3          699          0       1       0.00              2          0
# 4          850          2       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Age_new  Gender_new Age_bins
# 0               1        101348.88       1     42.0           0    41-60
# 1               1        112542.58       0     41.0           0    41-60
# 2               0        113931.57       1     42.0           0    41-60
# 3               0         93826.63       0     39.0           0    21-40
# 4               1         79084.10       0     43.0           0    41-60

# %%
#Analysis of the customers who are likely to churn based on credit score:

sns.kdeplot(data=df,x="CreditScore",hue="Exited",fill=True)
plt.grid(alpha=0.3,linestyle=":")
plt.axvline(650,c="yellow",alpha=0.4)

# %% [markdown]
# #  ANALYSIS:
#     The customers with the credit score 600-700 are more likely to churn

# %% [markdown]
# # BI-VARIATE ANALYSIS:

# %%
#Analyzing the customers age with respect to balance who are likely to churn:

sns.scatterplot(data=df,x="Age_new",y="Balance",hue="Exited")
# Out:
# <Axes: xlabel='Age_new', ylabel='Balance'>

# %% [markdown]
# # Analysis:
#
# The customers with 50-60 of age and with 100000-150000 balance are more likely to churn

# %%
#Analysis of customers age with creditscore who are likely to churn:

sns.scatterplot(data=df,x="Age_new",y="CreditScore",hue="Exited")
# Out:
# <Axes: xlabel='Age_new', ylabel='CreditScore'>

# %% [markdown]
# # Analysis:
#
#     The customers with 50-60 age group with credit card are more likely to churn.

# %%
#To identify whether the outliers are present in dataset:

df.boxplot(patch_artist=True,figsize=(12,6))
plt.xticks(rotation=90)
plt.grid(visible=None)
plt.title("BoxPlot")
plt.show()

# %% [markdown]
# # Analysis:
#
# By the Boxplot we can understand that there are no outliers in the dataset.
